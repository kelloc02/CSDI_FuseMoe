# %%
import torch

x = torch.randn(4, 2, 3)   # 正态分布随机数
print(x)
# Out:
# tensor([[[ 2.1177,  0.5277,  0.3779],
#          [-1.9148,  0.3184, -1.0295]],
#
#         [[ 0.2439, -0.9831, -0.6240],
#          [ 0.8829, -0.9999, -0.9906]],
#
#         [[ 0.2889,  0.3648,  1.6710],
#          [-0.1952, -0.4316, -0.8624]],
#
#         [[-1.0807, -1.1774,  0.4293],
#          [-0.9834, -0.9928,  0.4254]]])

# %%
torch.max(x, dim=0).values
# Out:
# tensor([[2.1177, 0.5277, 1.6710],
#         [0.8829, 0.3184, 0.4254]])

# %%
import torch.nn as nn   
import torch
e = nn.Embedding(4, 128)
e(torch.zeros((48, 111), dtype=torch.long)).shape

x = torch.randn([48, 111, 128]) 
x+=e
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       4 e(torch.zeros((48, 111), dtype=torch.long)).shape
#       6 x = torch.randn([48, 111, 128])
# ----> 7 x+=e
#
# TypeError: unsupported operand type(s) for +=: 'Tensor' and 'Embedding'
